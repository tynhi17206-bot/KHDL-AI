# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Try to load the data with error handling
try:
    # Try different possible filenames
    possible_files = [
        'financial_statement_anomaly_dataset.csv',
        'Financial Statement Anomaly Dataset.csv',
        'dataset.csv'
    ]
    
    df = None
    for filename in possible_files:
        try:
            df = pd.read_csv(filename)
            print(f"Successfully loaded: {filename}")
            break
        except FileNotFoundError:
            continue
    
    if df is None:
        print("Dataset file not found. Please check the filename and path.")
        print("Available files in current directory:")
        import os
        print([f for f in os.listdir('.') if f.endswith('.csv')])
    else:
        # Step 2: Basic exploration (safe)
        print("Dataset Shape:", df.shape)
        print("\nColumn Names:")
        print(df.columns.tolist())
        print("\nFirst 3 rows:")
        print(df.head(3))
        print("\nData types:")
        print(df.dtypes)
        
        # Step 3: Check for target column
        if 'Anomaly' in df.columns:
            print("\nTarget variable found!")
            print("Anomaly distribution:")
            print(df['Anomaly'].value_counts())
        else:
            print("\nAvailable columns for potential target:")
            print(df.columns.tolist())

except Exception as e:
    print(f"Error occurred: {e}")
    print("Please share this error message for specific help.")
# Out:
# Dataset file not found. Please check the filename and path.
# Available files in current directory:
# ['financial_statement.csv']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Try to load the data with error handling
try:
    # Try different possible filenames
    possible_files = [
        'financial_statement_anomaly_dataset.csv',
        'Financial Statement Anomaly Dataset.csv',
        'dataset.csv'
    ]
    
    df = None
    for filename in possible_files:
        try:
            df = pd.read_csv(filename)
            print(f"Successfully loaded: {filename}")
            break
        except FileNotFoundError:
            continue
    
    if df is None:
        print("Dataset file not found. Please check the filename and path.")
        print("Available files in current directory:")
        import os
        print([f for f in os.listdir('.') if f.endswith('.csv')])
    else:
        # Step 2: Basic exploration (safe)
        print("Dataset Shape:", df.shape)
        print("\nColumn Names:")
        print(df.columns.tolist())
        print("\nFirst 3 rows:")
        print(df.head(3))
        print("\nData types:")
        print(df.dtypes)
        
        # Step 3: Check for target column
        if 'Anomaly' in df.columns:
            print("\nTarget variable found!")
            print("Anomaly distribution:")
            print(df['Anomaly'].value_counts())
        else:
            print("\nAvailable columns for potential target:")
            print(df.columns.tolist())

except Exception as e:
    print(f"Error occurred: {e}")
    print("Please share this error message for specific help.")
# Out:
# Successfully loaded: Financial Statement Anomaly Dataset.csv
# Dataset Shape: (4000, 14)
#
# Column Names:
# ['Total_Assets', 'Total_Liabilities', 'Revenue', 'Operating_Expenses', 'Net_Income', 'Cash_Flow_Operating', 'Cash_Flow_Investing', 'Cash_Flow_Financing', 'Current_Ratio', 'Debt_to_Equity', 'Gross_Margin', 'Return_on_Assets', 'Return_on_Equity', 'Financial_Status']
#
# First 3 rows:
#    Total_Assets  Total_Liabilities   Revenue  Operating_Expenses  Net_Income  \
# 0     -0.248887           0.172661  0.455813            0.316469   -1.063207
# 1      0.889568           0.643670  0.389065           -0.798999   -1.071656
# 2      0.457401           0.552325 -0.807953           -0.483753   -0.092340
#
#    Cash_Flow_Operating  Cash_Flow_Investing  Cash_Flow_Financing  \
# 0             0.430494             0.384236             0.506206
# 1            -0.663768            -0.064779            -0.462247
# 2            -0.338535            -0.913264             0.322580
#
# ...

# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install pandas matplotlib seaborn scikit-learn
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 3.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.7 MB 7.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.7 MB 9.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.7 MB 7.3 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.7 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 7.8 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.2 MB 11.8 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.2 MB 11.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
import os

os.listdir()
# Out:
# ['.ai-navigator',
#  '.anaconda',
#  '.conda',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.Ld9VirtualBox',
#  '.matplotlib',
#  '.MUMUVMM',
#  '3D Objects',
#  'anaconda3',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'BrawlhallaReplays',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Financial Statement Anomaly Dataset.csv',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{273eb7a3-a46f-11ed-8153-9828a6115bbc}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{273eb7a3-a46f-11ed-8153-9828a6115bbc}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{273eb7a3-a46f-11ed-8153-9828a6115bbc}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{273eb7a3-a46f-11ed-8153-9828a6115bbc}.TxR.blf',
#  'NTUSER.DAT{273eb7a4-a46f-11ed-8153-9828a6115bbc}.TM.blf',
# ...

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
df = pd.read_csv("financial_statement.csv")

# %%
print("Kích thước:", df.shape)

print("\n5 dòng đầu:")
print(df.head())

print("\nThông tin dữ liệu:")
print(df.info())
# Out:
# Kích thước: (4000, 14)
#
# 5 dòng đầu:
#    Total_Assets  Total_Liabilities   Revenue  Operating_Expenses  Net_Income  \
# 0     -0.248887           0.172661  0.455813            0.316469   -1.063207
# 1      0.889568           0.643670  0.389065           -0.798999   -1.071656
# 2      0.457401           0.552325 -0.807953           -0.483753   -0.092340
# 3      0.193945          -0.670940  0.865197            0.548338   -1.011553
# 4     -0.680661          -0.680323  0.148639            0.072464    0.949925
#
#    Cash_Flow_Operating  Cash_Flow_Investing  Cash_Flow_Financing  \
# 0             0.430494             0.384236             0.506206
# 1            -0.663768            -0.064779            -0.462247
# 2            -0.338535            -0.913264             0.322580
# 3             0.296656             0.864205             0.412764
# 4            -0.066819             0.991559            -0.296009
#
#    Current_Ratio  Debt_to_Equity  Gross_Margin  Return_on_Assets  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Total_Assets', 'Total_Liabilities', 'Revenue', 'Operating_Expenses',
#        'Net_Income', 'Cash_Flow_Operating', 'Cash_Flow_Investing',
#        'Cash_Flow_Financing', 'Current_Ratio', 'Debt_to_Equity',
#        'Gross_Margin', 'Return_on_Assets', 'Return_on_Equity',
#        'Financial_Status'],
#       dtype='str')

# %%
df = df.fillna(0)

# %%
target_col = "Financial_Status"

X = df.drop(columns=[target_col])
y = df[target_col]

# %%
X = X.select_dtypes(include=['int64','float64'])

print("Số feature:", X.shape[1])
# Out:
# Số feature: 13

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(10,7))

sns.scatterplot(
    x=X_pca[:,0],
    y=X_pca[:,1],
    hue=y,
    palette="Set1"
)

plt.title("PCA Financial Space")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
model = RandomForestClassifier(
    n_estimators=200,
    class_weight="balanced",
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      Anomaly       0.00      0.00      0.00       157
#    High Risk       0.00      0.00      0.00        85
#       Normal       0.70      1.00      0.82       558
#
#     accuracy                           0.70       800
#    macro avg       0.23      0.33      0.27       800
# weighted avg       0.49      0.70      0.57       800

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

# %%
acc = accuracy_score(y_test, y_pred)

print("Accuracy:", acc)
# Out:
# Accuracy: 0.6975

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Admin
